# %% [markdown]
# <a href="https://colab.research.google.com/github/styndall/nlp_tools/blob/master/AI_Lovecraft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install the GPT-2 simple python interface and check which GPU we've been assigned

# %%
# !pip install -q gpt-2-simple
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Tue Mar 30 20:23:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import gpt_2_simple as gpt2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 464Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.56Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 541Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:09, 50.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 591Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.59Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.38Mit/s]

# %%
file_name = "uta_lyrics.txt"

# %% [markdown]
# Below, start the session and retrain on the lyric data

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=100,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=20,
              save_every=50
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00,  7.42it/s]
# Loading dataset...
# dataset has 14427 tokens
# Training...
# [10 | 28.97] loss=3.31 avg=3.31
# [20 | 53.48] loss=2.90 avg=3.10
# ======== SAMPLE 1 ========
# , and will remain so when he steps forward. This is what the gods know, that this world will never end, nor do they allow us to know what is ahead. I cannot trust them to return us to the light
#
# It is the way that I will go, and I know I have no choice but to lead
#
# This world is coming to an end, and I'm doomed
#
# And there lies the path you've chosen
# ...

# %%
gpt2.generate(sess,
              prefix="broken by",
              length=100,
              temperature=1.2,
              top_p=0.9,
              nsamples=5,
              batch_size=5
              )
# Out:
# broken by night)<|endoftext|>Among the strangest chapters of Bibliothèque
# This tale is told through the eyes of a twelve year old boy who lives his life to the risk
# No matter how worthy a job it may be, there's no escaping it, he's been through so much
# He can't help but feel guilty, he can't bear to bear to see his turn brought to an end
# When his heart turns red he knows that he's done with life
#
# There's no
# ...
# broken by a waterfall in The Ragged Hand
# The tension is such that one must feel no pain
# I see the power in the form of a serpent
# Charging through the crowd
# It is easy to become captivated
# Caused by passions I outgrow
# Quick to anger, quick to anger anger will run
#
# Will spill over his fingers and sing, "In the name of the dead I am here, in the name of the living I am here"
#
# [CHORUS:]
# ...
# broken by fire
# Light me not with hallowed titles
# I will bring them home
#
# Child of the mountain
# Created with the plague
# She can break from time and again
# ...
